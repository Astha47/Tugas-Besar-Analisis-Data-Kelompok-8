# %% [markdown]
# ## Membaca data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('vgsalesGlobale.csv')
data
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# ## Penjelasan data yang digunakan
#
# Data yang kita gunakan merupakan data penjualan game secara global\
# format data kita adalah **csv** atau dengan nama lain "comma seperated values"\
# ukuran file kita adalah 1.29 MB
# dimensi dan total elemen dari data kita adalah sebagai berikut :

# %%
data.shape 
    # menampilkan dimensi dari data
    # (baris,kolom)
# Out:
# (16598, 11)

# %%
data.size
    # menampilkan total elemen data
# Out:
# 182578

# %% [markdown]
# ## Penjelasan atribut/kolom

# %% [markdown]
# Data kita mengandung kolom-kolom sebagai berikut

# %%
data.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %% [markdown]
# Data type dari setiap kolom adalah sebagai berikut

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# Tipe data yang terdapat pada tiap kolom bersifat sebagai berikut :
# - Rank : Categorical - Ordinal
# - Name, Platform, Genre, Publisher : Categorical - Nominal
# - Year : Quantitative - Continues
# - NA_Sales, EU_Sales, JP_Sales, Other_Sales, Global_Sales : Quantitative - Discrete

# %% [markdown]
# Karakteristik - karakteristik yang terdapat pada kolom adalah sebagai berikut :
# - Rank : terdiri dari angka yang 1 hingga 16600 dengan 1 adalah game dengan Global_Sales terbanyak dan angka terbesar adalah game dengan Global_Sales paling sedikit
# - Name : Terdiri dari nama - nama game
# - Platform : sistem yang digunakan untuk menjalankan game, data pada kolom ini terdiri dari:

# %%
data["Platform"].unique()
# Out:
# array(['Wii', 'NES', 'GB', 'DS', 'X360', 'PS3', 'PS2', 'SNES', 'GBA',
#        '3DS', 'PS4', 'N64', 'PS', 'XB', 'PC', '2600', 'PSP', 'XOne', 'GC',
#        'WiiU', 'GEN', 'DC', 'PSV', 'SAT', 'SCD', 'WS', 'NG', 'TG16',
#        '3DO', 'GG', 'PCFX'], dtype=object)

# %% [markdown]
# - Year : Tahun rilis game, rentang tahunnya adalah:

# %%
maxy = data["Year"].max()
miny = data["Year"].min()
print (str(int(miny)),end= " - ")
print(str(int(maxy)))
# Out:
# 1980 - 2020

# %% [markdown]
# - Genre: Genre dari tiap game , kolom ini terdiri dari:

# %%
data["Genre"].unique()
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy'], dtype=object)

# %% [markdown]
# - Publisher : Perusahaan yang menerbitkan game tersebut, kolom ini terdiri dari :

# %%
len(data["Publisher"].unique())
# Out:
# 579

# %% [markdown]
# - NA_Sales : penjualan suatu video game di region North America, rangenya adalah :

# %%
maxna = data["NA_Sales"].max()
minna = data["NA_Sales"].min()
print (str(minna),end= " - ")
print(str(maxna),end = " ")
print("(dalam juta copy)")
# Out:
# 0.0 - 41.49 (dalam juta copy)

# %% [markdown]
# - EU_Sales : penjualan suatu video game di region European Union, rangenya adalah :

# %%
maxeu = data["EU_Sales"].max()
mineu = data["EU_Sales"].min()
print (str(mineu),end= " - ")
print(str(maxeu),end = " ")
print("(dalam juta copy)")
# Out:
# 0.0 - 29.02 (dalam juta copy)

# %% [markdown]
# - JP_Sales : penjualan suatu video game di region Jepang, rangenya adalah :

# %%
maxjp = data["JP_Sales"].max()
minjp = data["JP_Sales"].min()
print (str(minjp),end= " - ")
print(str(maxjp),end = " ")
print("(dalam juta copy)")
# Out:
# 0.0 - 10.22 (dalam juta copy)

# %% [markdown]
# - Other_Sales: penjualan yang tidak berada di region North America , European Unio, maupun Jepang. Rangenya adalah :

# %%
maxot = data["Other_Sales"].max()
minot = data["Other_Sales"].min()
print (str(minot),end= " - ")
print(str(maxot),end = " ")
print("(dalam juta copy)")
# Out:
# 0.0 - 10.57 (dalam juta copy)

# %% [markdown]
# - Global_Sales  penjualan total secara keseluruhan, kolom rank juga mengacu pada kolom ini. Rangenya adalah:

# %%
maxgl = data["Global_Sales"].max()
mingl = data["Global_Sales"].min()
print (str(mingl),end= " - ")
print(str(maxgl),end = " ")
print("(dalam juta copy)")
# Out:
# 0.01 - 82.74 (dalam juta copy)

# %% [markdown]
# ## Presentase data kosong

# %%
# Untuk mempermudah data cleaning, kita mengubah semua nilai 0 menjadi NA
data.replace(0,np.nan,inplace=True)

# %%
x = (data.isna().sum().sum()/data.size)*100
print("{:.2f}%".format(x))
# Out:
# 15.06%

# %% [markdown]
# ## Data cleaning and Data Sample

# %% [markdown]
# ### Mengecek null data

# %%
data.isna().sum()
    # mengecek kolom yang mengandung data null
    # kolom yang mengandung data null dalam data kita adalah kulom Year, Publisher, NA_Salse, EU_Sales, JP_Sales, Other_Sales
# Out:
# Rank                0
# Name                0
# Platform            0
# Year              271
# Genre               0
# Publisher          58
# NA_Sales         4499
# EU_Sales         5730
# JP_Sales        10455
# Other_Sales      6477
# Global_Sales        0
# dtype: int64

# %% [markdown]
# Dalam data kita, kolom yang tidak boleh null adalah kolom Rank, Name, Platform, Year, Genre, Publisher

# %% [markdown]
# Baris-baris yang mengandung null value pada kolom tersebut akan dibuang

# %%
#data.dropna(subset=['Rank','Name','Platform','Year','Genre',"Publisher"],inplace=True)
    # Menghapus baris yang mengandung null value pada kolom-kolom dalam list subset
data.dropna(subset=['Rank','Name','Platform','Year','Genre'],inplace=True)

# %% [markdown]
# Baris-baris yang memiliki null data pada kolom sales dapat berarti pada daerah tersebut game yang mengandung null value tidak di jual\
# Tetapi, baris yang mengandung null value pada seluruh kolom sales perlu dibuang

# %%
data.dropna(subset=["NA_Sales","EU_Sales","JP_Sales","Other_Sales","Global_Sales"],how='all',inplace=True)

# %% [markdown]
# Untuk mempermudah analisis data, kita jadikan kolom "Rank" sebagai index data

# %%
data.set_index('Rank',inplace=True)

# %% [markdown]
# Data null hanya tersisah pada kolom-kolom sales saja, maka kita ganti null value tersebut dengan angka 0 (tidak dijual pada daerah tersebut)

# %%
data.fillna(0,inplace=True)

# %% [markdown]
# ### Mengecek tahun data

# %% [markdown]
# Ketahui bahwa tahun maksimal data csv seharusnya tahun 2017, maka setiap baris yang memiliki tahun di atas 2017 perlu di buang

# %%
data.drop(index=data.loc[data['Year'] > 2017].index,inplace=True)

# %%
data.loc[data['Year'] > 2017]
    # baris dengan tahun lebih dari 2017 sudah di buang
# Out:
# Empty DataFrame
# Columns: [Name, Platform, Year, Genre, Publisher, NA_Sales, EU_Sales, JP_Sales, Other_Sales, Global_Sales]
# Index: []

# %% [markdown]
# ### Mencari data duplikat

# %% [markdown]
# Ketahui bahwa data duplikat yang logis terjadi pada kolom "Name"

# %%
data.duplicated(subset=['Name'],keep=False).sum()
    # terdapat 7682 baris yang memiliki nama game yang sama dengan baris yang lain
# Out:
# 7684

# %%
data.loc[data.duplicated(subset=['Name'],keep=False)]
    # menampilkan baris-baris dengan nama duplikat
# Out:
#                                                    Name Platform    Year  \
# Rank
# 2                                     Super Mario Bros.      NES  1985.0
# 6                                                Tetris       GB  1989.0
# 17                                   Grand Theft Auto V      PS3  2013.0
# 18                        Grand Theft Auto: San Andreas      PS2  2004.0
# 19                                    Super Mario World     SNES  1990.0
# ...                                                 ...      ...     ...
# 16589                    Secret Files 2: Puritas Cordis       DS  2009.0
# 16594                               Myst IV: Revelation       PC  2004.0
# 16597                     Men in Black II: Alien Escape       GC  2003.0
# 16598  SCORE International Baja 1000: The Official Game      PS2  2008.0
# 16600                                  Spirits & Spells      GBA  2003.0
#
#            Genre             Publisher  NA_Sales  EU_Sales  JP_Sales  \
# Rank
# ...

# %% [markdown]
# Mengapa hal tersebut terjadi ? mari kita ambil satu contoh

# %%
data.loc[data['Name'] == "Super Mario Bros."]
# Out:
#                    Name Platform    Year     Genre Publisher  NA_Sales  \
# Rank
# 2     Super Mario Bros.      NES  1985.0  Platform  Nintendo     29.08
# 201   Super Mario Bros.       GB  1999.0  Platform  Nintendo      3.40
#
#       EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Rank
# 2         3.58      6.81         0.77         40.24
# 201       1.30      0.15         0.22          5.07

# %% [markdown]
# Dapat di lihat dengan contoh di atas bahwa walaupun kedua baris sama, tetapi masing-masing memiliki Platform berbeda\
# Hal ini berlaku untuk semua data dengan nama duplikat di atas

# %% [markdown]
# Dalam percobaan kali ini, data dengan duplikat-duplikat tersebut akan dianggap sebagai data unique sehingga tidak akan di buang

# %% [markdown]
# Mengubah data type tahun menjadi integer (tahun tidak mungkin float)

# %%
data['Year'] = data['Year'].astype(int)

# %% [markdown]
# ## Mengambil sample 300 baris pertama pada data yang sudah dibersihkan

# %%
sample = data.iloc[0:300].copy()

# %%
sample
# Out:
#                                          Name Platform  Year         Genre  \
# Rank
# 1                                  Wii Sports      Wii  2006        Sports
# 2                           Super Mario Bros.      NES  1985      Platform
# 3                              Mario Kart Wii      Wii  2008        Racing
# 4                           Wii Sports Resort      Wii  2009        Sports
# 5                    Pokemon Red/Pokemon Blue       GB  1996  Role-Playing
# ...                                       ...      ...   ...           ...
# 297                               Star Fox 64      N64  1997       Shooter
# 298                                 Minecraft      PS4  2014          Misc
# 299                                      Golf      NES  1984        Sports
# 300                                 Fallout 3      PS3  2008  Role-Playing
# 301   Professor Layton and the Diabolical Box       DS  2007        Puzzle
#
# ...

# %% [markdown]
# ### Statistik Pada Sample

# %%
sample[['NA_Sales','EU_Sales',"JP_Sales","Global_Sales"]].describe(percentiles = [.1,.25,.50,.75,.90])
# Out:
#          NA_Sales    EU_Sales    JP_Sales  Global_Sales
# count  300.000000  300.000000  300.000000    300.000000
# mean     3.997000    2.476367    1.090767      8.339233
# std      4.094026    2.472043    1.539014      7.284455
# min      0.000000    0.000000    0.000000      4.000000
# 10%      1.372000    0.630000    0.010000      4.200000
# 25%      2.147500    1.240000    0.067500      4.680000
# 50%      2.965000    1.930000    0.305000      5.835000
# 75%      4.257500    2.835000    1.572500      8.885000
# 90%      6.992000    4.511000    3.280000     14.652000
# max     41.490000   29.020000   10.220000     82.740000

# %% [markdown]
# # Visualisasi dan Analisis Data

# %% [markdown]
# ## Hubungan Penjualan Tiap Region

# %% [markdown]
# #### Penjualan Tiap Wilayah

# %%
def SUM(tipe):
    Sales = sample[tipe]
    jumlah = 0
    for i in range(len(Sales)):
        jumlah = jumlah + Sales.iloc[i]
    return jumlah

NA = SUM('NA_Sales')
EU = SUM('EU_Sales')
JP = SUM('JP_Sales')
Other = SUM('Other_Sales')

salesTP = [['NA',NA],['EU',EU],['JP',JP],['Other',Other]]
sales = pd.DataFrame(salesTP, columns=['Region','Total Sales'])
sales.plot(kind="bar",x="Region",title="Sales", ylabel="Penjualan")
# Out:
# <AxesSubplot: title={'center': 'Sales'}, xlabel='Region', ylabel='Penjualan'>

# %% [markdown]
# #### Grafik North America terhadap Europe

# %%
data.plot(kind="scatter", x="EU_Sales", y="NA_Sales")
nilai_korelasi = data['EU_Sales'].corr(data['NA_Sales'])
print("Dengan nilai korelasi sebesar : ",nilai_korelasi)
if nilai_korelasi>0.5:
    print("Kedua nilai berbanding lurus karena nilai korelasi mendekati 1")
elif nilai_korelasi > -0.5:
    print("Kedua nilai tidak berkorelasi karena nilai korelasi mendekati 0")
else:
    print("Kedua nilai berbanding terbalik karena nilai korelasi mendekati -1")
# Out:
# Dengan nilai korelasi sebesar :  0.7689383432122567
# Kedua nilai berbanding lurus karena nilai korelasi mendekati 1

# %% [markdown]
# #### Grafik North America terhadap Japan

# %%
data.plot(kind="scatter", x="JP_Sales", y="NA_Sales")
nilai_korelasi = data['JP_Sales'].corr(data['NA_Sales'])
print("Dengan nilai korelasi sebesar : ",nilai_korelasi)
if nilai_korelasi>0.5:
    print("Kedua nilai berbanding lurus karena nilai korelasi mendekati 1")
elif nilai_korelasi > -0.5:
    print("Kedua nilai tidak berkorelasi karena nilai korelasi mendekati 0")
else:
    print("Kedua nilai berbanding terbalik karena nilai korelasi mendekati -1")
# Out:
# Dengan nilai korelasi sebesar :  0.45128634410341273
# Kedua nilai tidak berkorelasi karena nilai korelasi mendekati 0

# %% [markdown]
# #### Grafik Europe terhadap Japan

# %%
data.plot(kind="scatter", x="JP_Sales", y="EU_Sales")
nilai_korelasi = data['JP_Sales'].corr(data['EU_Sales'])
print("Dengan nilai korelasi sebesar : ",nilai_korelasi)
if nilai_korelasi>0.5:
    print("Kedua nilai berbanding lurus karena nilai korelasi mendekati 1")
elif nilai_korelasi > -0.5:
    print("Kedua nilai tidak berkorelasi karena nilai korelasi mendekati 0")
else:
    print("Kedua nilai berbanding terbalik karena nilai korelasi mendekati -1")
# Out:
# Dengan nilai korelasi sebesar :  0.436411437311185
# Kedua nilai tidak berkorelasi karena nilai korelasi mendekati 0

# %% [markdown]
# ### Analisis Data

# %% [markdown]
# 1. Dari kesesuaian data, didapatkan bahwa terjadi gap besar antara game yang dipasarkan di North Amerika dan Europe dengan yang di Japan. Game yang sukses di pasar Amerika Utara bisa dibilang akan sukses di pasar Eropa namun menjadi tantangan besar di Jepang maupun sebaliknya walaupun ada game yang bisa sukses di kedua pasar.
# 2. North America merupakan pasar potensial dalam penjualan game.

# %% [markdown]
# ## Visualisasi Data Game Berdasarkan Publisher

# %% [markdown]
# ### Jumlah Kontribusi Publisher

# %%
#Pie chart Publisher Contribution All the time
#data.value_counts("Publisher").head(10).plot(kind = "pie")
plot = data.value_counts("Publisher").head(10).plot(kind="barh",title="Jumlah Kontribusi Publisher")
plot.set_xlabel("Produksi Game")
plot.set_ylabel("Publisher")
# Out:
# Text(0, 0.5, 'Publisher')

# %%
#creating publisher list

# LOADER

sorted_publisher = data.value_counts("Publisher")

input_data_publisher = {}
input_data_publisher["Publisher"] = ["a" for i in range(len(sorted_publisher))]

for j in range(len(sorted_publisher)):
    input_data_publisher["Publisher"][j] = sorted_publisher.index[j]
list_publisher = pd.DataFrame(data=input_data_publisher)

list_publisher
# Out:
#                         Publisher
# 0                 Electronic Arts
# 1                      Activision
# 2              Namco Bandai Games
# 3                         Ubisoft
# 4    Konami Digital Entertainment
# ..                            ...
# 572            Illusion Softworks
# 573              ITT Family Games
# 574               Her Interactive
# 575                   Hello Games
# 576                         Locus
#
# [577 rows x 1 columns]

# %%
sorted_publisher
# Out:
# Publisher
# Electronic Arts                 1339
# Activision                       966
# Namco Bandai Games               928
# Ubisoft                          917
# Konami Digital Entertainment     823
#                                 ...
# Illusion Softworks                 1
# ITT Family Games                   1
# Her Interactive                    1
# Hello Games                        1
# Locus                              1
# Length: 577, dtype: int64

# %% [markdown]
# ### Intesifitas Produksi Publisher Spesifik

# %%
pilihan_publisher =int(input("Masukkan pilihan publisher : "))
keyword = list_publisher['Publisher'].iloc[pilihan_publisher]

#memuat data publisher
hasil_search = data.loc[data['Publisher'] == keyword]
publish_publisher = hasil_search.value_counts('Year')

input_data_publisher = {}
input_data_publisher["Tahun"] = [0 for i in range(len(publish_publisher))]
input_data_publisher["Pertambahan"] = [0 for i in range(len(publish_publisher))]

for i in range(len(publish_publisher)):
    input_data_publisher["Tahun"][i] = publish_publisher.index[i]
for j in range(len(publish_publisher)):
    input_data_publisher["Pertambahan"][j] = publish_publisher.iloc[j]
data_publisher = pd.DataFrame(data=input_data_publisher)

data_publisher_sorted = data_publisher.sort_values('Tahun',ascending=True)

input_data = {}
input_data["Tahun"] = [0 for i in range(len(data_publisher_sorted))]
input_data["Jumlah"] = [0 for i in range(len(data_publisher_sorted))]

for i in range(len(data_publisher_sorted)):
    input_data["Tahun"][i] = data_publisher_sorted['Tahun'].iloc[i]
jumlah = 0

for j in range(len(data_publisher_sorted)):
    jumlah += data_publisher_sorted['Pertambahan'].iloc[j]
    input_data["Jumlah"][j] = jumlah
JumlahTiapTahun = pd.DataFrame(data=input_data)

title1 = "Produksi Game " + keyword
title2 = "Jumlah Game "+ keyword
graph = data_publisher.sort_values('Tahun').plot(kind="line",x="Tahun",y="Pertambahan",title=title1)
graph.set_xlabel("Tahun")
graph.set_ylabel("Jumlah Pertambahan")

graph = JumlahTiapTahun.plot(kind="line",x="Tahun",y="Jumlah", title=title2)
graph.set_xlabel("Tahun")
graph.set_ylabel("Jumlah Game")
# Out:
# Text(0, 0.5, 'Jumlah Game')

# %% [markdown]
# ### Visualisasi Data Produksi 10 Publisher Teratas

# %%
import math
from matplotlib import pyplot as plt

DataTahunTerakhir = []
DataNamaPublisher = []
for i in range(10):
    keyword = list_publisher['Publisher'].iloc[i]

    #memuat data publisher
    hasil_search = data.loc[data['Publisher'] == keyword]
    publish_publisher = hasil_search.value_counts('Year')

    input_data_publisher = {}
    input_data_publisher["Tahun"] = [0 for i in range(len(publish_publisher))]
    input_data_publisher["Pertambahan"] = [0 for i in range(len(publish_publisher))]

    for i in range(len(publish_publisher)):
        input_data_publisher["Tahun"][i] = publish_publisher.index[i]
    for j in range(len(publish_publisher)):
        input_data_publisher["Pertambahan"][j] = publish_publisher.iloc[j]
    data_publisher = pd.DataFrame(data=input_data_publisher)

    data_publisher_sorted = data_publisher.sort_values('Tahun',ascending=True)

    input_data = {}
    input_data["Tahun"] = [0 for i in range(len(data_publisher_sorted))]
    input_data["Jumlah"] = [0 for i in range(len(data_publisher_sorted))]

    for i in range(len(data_publisher_sorted)):
        input_data["Tahun"][i] = data_publisher_sorted['Tahun'].iloc[i]
    jumlah = 0

    for j in range(len(data_publisher_sorted)):
        jumlah += data_publisher_sorted['Pertambahan'].iloc[j]
        input_data["Jumlah"][j] = jumlah
    JumlahTiapTahun = pd.DataFrame(data=input_data)

    title1 = "Produksi Game " + keyword
    title2 = "Jumlah Game "+ keyword
    
    data_publisher.sort_values('Tahun').plot(kind="line",x="Tahun",y="Pertambahan",title=title1, xlabel="Tahun", ylabel="Pertambahan").locator_params(integer=True)

    JumlahTiapTahun.plot(kind="line",x="Tahun",y="Jumlah", title=title2, xlabel="Tahun", ylabel="Jumlah").locator_params(integer=True)

    tahunterakhir = [data_publisher.max().loc['Tahun']]
    DataNamaPublisher += [keyword]
    DataTahunTerakhir = DataTahunTerakhir + tahunterakhir
    
DataTahun = {}

DataTahun["Publisher"] = DataNamaPublisher
DataTahun["Tahun Terakhir Perilisan"] = DataTahunTerakhir
DataKeaktifan = pd.DataFrame(data=DataTahun)

plt.show()

# %% [markdown]
# ### Data Keaktifan Publisher

# %%
DataKeaktifan.sort_values('Tahun Terakhir Perilisan', ascending=False)
# Out:
#                       Publisher  Tahun Terakhir Perilisan
# 8                          Sega                      2017
# 0               Electronic Arts                      2016
# 1                    Activision                      2016
# 2            Namco Bandai Games                      2016
# 3                       Ubisoft                      2016
# 4  Konami Digital Entertainment                      2016
# 6                      Nintendo                      2016
# 7   Sony Computer Entertainment                      2016
# 9          Take-Two Interactive                      2016
# 5                           THQ                      2013

# %% [markdown]
# ### Analisis Data
#
# Dari data yang  didapat, dijelaskan untuk kurun waktu 1983-2017 bahwa terdapat publisher yang mengeluarkan game terbaru pada kurun waktu 2016-2017. Maka untuk mendapatkan game terbaru sesuai data dapat melakukan peneleusuran pada publisher tersebut.

# %%
DataKeaktifan.sort_values('Tahun Terakhir Perilisan', ascending=False).head(17)
# Out:
#                       Publisher  Tahun Terakhir Perilisan
# 8                          Sega                      2017
# 0               Electronic Arts                      2016
# 1                    Activision                      2016
# 2            Namco Bandai Games                      2016
# 3                       Ubisoft                      2016
# 4  Konami Digital Entertainment                      2016
# 6                      Nintendo                      2016
# 7   Sony Computer Entertainment                      2016
# 9          Take-Two Interactive                      2016
# 5                           THQ                      2013

# %% [markdown]
# ## Visualisasi Data Game Berdasarkan Dukungan Platform

# %% [markdown]
# #### Data 10 Platform Teratas

# %%
#Pie chart Platform All the time
data.value_counts("Platform").head(15).plot(kind = "pie",title="Jumlah Game Berdasarkan Platform")
# Out:
# <AxesSubplot: title={'center': 'Jumlah Game Berdasarkan Platform'}>

# %% [markdown]
# #### Visualisasi Data Pertambahan Produksi Game Tiap Tahun

# %%
#umlah game setiap tahun


DFJumlah = data.value_counts("Year")

input_data = {}
input_data["Tahun"] = [0 for i in range(len(DFJumlah))]
input_data["Pertambahan"] = [0 for i in range(len(DFJumlah))]

for i in range(len(DFJumlah)):
    input_data["Tahun"][i] = DFJumlah.index[i]
for j in range(len(DFJumlah)):
    input_data["Pertambahan"][j] = DFJumlah.iloc[j]
NewDataFrame = pd.DataFrame(data=input_data)

NewJumlahDataFrame = pd.DataFrame(data=input_data)

DataPertambahan = NewDataFrame.sort_values('Tahun',ascending=True)

input_data = {}
input_data["Tahun"] = [0 for i in range(len(DataPertambahan))]
input_data["Jumlah"] = [0 for i in range(len(DataPertambahan))]

for i in range(len(DataPertambahan)):
    input_data["Tahun"][i] = DataPertambahan['Tahun'].iloc[i]

jumlah = 0
for j in range(len(DataPertambahan)):
    jumlah += DataPertambahan['Pertambahan'].iloc[j]
    input_data["Jumlah"][j] = jumlah
JumlahTiapTahun = pd.DataFrame(data=input_data)


DataPertambahan.plot(kind="line",x="Tahun",y="Pertambahan",title="Pertambahan Game Tiap Tahun")
JumlahTiapTahun.plot(kind="line",x="Tahun",y="Jumlah",title="Jumlah Game Tiap Tahun")
# Out:
# <AxesSubplot: title={'center': 'Jumlah Game Tiap Tahun'}, xlabel='Tahun'>

# %% [markdown]
# #### Mencari Game Dengan Kategori Rilis Terbaru
# Dikategorikan sebagai game yang rilis mulai dari 2013, bersamaan dengan rilisnya PS4.

# %%
SortedPublishYear = data.sort_values('Year', ascending= False)
SortedPublishYear.loc[SortedPublishYear['Year']>=2013]
# Out:
#                                                    Name Platform  Year  \
# Rank
# 16441                  Brothers Conflict: Precious Baby      PSV  2017
# 16244  Phantasy Star Online 2 Episode 4: Deluxe Package      PSV  2017
# 14393  Phantasy Star Online 2 Episode 4: Deluxe Package      PS4  2017
# 3147                                           NBA 2K17     XOne  2016
# 15187                      Sengoku Otome: Legend Battle      PSV  2016
# ...                                                 ...      ...   ...
# 8893                         Major League Baseball 2K13      PS3  2013
# 1006                                     Kingdom Hearts      PS3  2013
# 5245                                           Defiance      PS3  2013
# 15819                               Winning Post 7 2013      PSV  2013
# 1355                 Dragon Quest VII: Warriors of Eden      3DS  2013
#
#               Genre             Publisher  NA_Sales  EU_Sales  JP_Sales  \
# Rank
# ...

# %% [markdown]
# #### Mencari Game dengan Penjualan Terbanyak Global

# %%
Terbanyak_Global = data.sort_values('Global_Sales',ascending=False)
Terbanyak_Global.loc[Terbanyak_Global['Global_Sales']>=10]
# Out:
#                                    Name Platform  Year         Genre  \
# Rank
# 1                            Wii Sports      Wii  2006        Sports
# 2                     Super Mario Bros.      NES  1985      Platform
# 3                        Mario Kart Wii      Wii  2008        Racing
# 4                     Wii Sports Resort      Wii  2009        Sports
# 5              Pokemon Red/Pokemon Blue       GB  1996  Role-Playing
# ...                                 ...      ...   ...           ...
# 58                Super Mario All-Stars     SNES  1993      Platform
# 59    Pokemon FireRed/Pokemon LeafGreen      GBA  2004  Role-Playing
# 60                       Super Mario 64       DS  2004      Platform
# 61                         Just Dance 3      Wii  2011          Misc
# 62                 Call of Duty: Ghosts     X360  2013       Shooter
#
#        Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Rank
# ...

# %% [markdown]
# #### Mengurutkan Game Terbaru dengan Penjualan Tertinggi

# %%
SortedPublishYear.loc[SortedPublishYear['Year']>=2013].sort_values('Global_Sales',ascending=False)
# Out:
#                                    Name Platform  Year         Genre  \
# Rank
# 17                   Grand Theft Auto V      PS3  2013        Action
# 24                   Grand Theft Auto V     X360  2013        Action
# 33                  Pokemon X/Pokemon Y      3DS  2013  Role-Playing
# 34            Call of Duty: Black Ops 3      PS4  2015       Shooter
# 45                   Grand Theft Auto V      PS4  2014        Action
# ...                                 ...      ...   ...           ...
# 16039  Utawarerumono: Futari no Hakuoro      PS3  2016          Misc
# 16031                 Wand of Fortune R      PSV  2016     Adventure
# 16101                Ben 10 Omniverse 2     X360  2013        Action
# 16127             Young Justice: Legacy     X360  2013        Action
# 16441  Brothers Conflict: Precious Baby      PSV  2017        Action
#
#                   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Rank
# ...

# %% [markdown]
# #### Menampilkan Data Kesediaan Platform

# %%
#pertambahan untuk tiap konsol

# LOADER

sorted_console = sample.value_counts("Platform")

input_data_konsol = {}
input_data_konsol["Jenis Konsol"] = ["a" for i in range(len(sorted_console))]

for j in range(len(sorted_console)):
    input_data_konsol["Jenis Konsol"][j] = sorted_console.index[j]
list_console = pd.DataFrame(data=input_data_konsol)

list_console
# Out:
#    Jenis Konsol
# 0          X360
# 1           PS3
# 2           PS2
# 3           Wii
# 4            PS
# 5            DS
# 6           PS4
# 7            GB
# 8           NES
# 9           3DS
# 10         SNES
# 11          N64
# 12          GBA
# 13           PC
# 14         WiiU
# 15         XOne
# 16          PSP
# 17           GC
# 18         2600
# 19          GEN
# 20           XB

# %% [markdown]
# #### Menampilkan Data Game Untuk Platform Spesifik

# %%
pilihan_konsol =int(input("Masukkan pilihan konsol : "))
keyword = list_console['Jenis Konsol'].iloc[pilihan_konsol]

#memuat data konsol
hasil_search = data.loc[data['Platform'] == keyword]
publish_konsol = hasil_search.value_counts('Year')

input_data_konsol = {}
input_data_konsol["Tahun"] = [0 for i in range(len(publish_konsol))]
input_data_konsol["Pertambahan"] = [0 for i in range(len(publish_konsol))]

for i in range(len(publish_konsol)):
    input_data_konsol["Tahun"][i] = publish_konsol.index[i]
for j in range(len(publish_konsol)):
    input_data_konsol["Pertambahan"][j] = publish_konsol.iloc[j]
data_konsol = pd.DataFrame(data=input_data_konsol)

data_konsol_sorted = data_konsol.sort_values('Tahun',ascending=True)

input_data = {}
input_data["Tahun"] = [0 for i in range(len(data_konsol_sorted))]
input_data["Jumlah"] = [0 for i in range(len(data_konsol_sorted))]

for i in range(len(data_konsol_sorted)):
    input_data["Tahun"][i] = data_konsol_sorted['Tahun'].iloc[i]
jumlah = 0

for j in range(len(data_konsol_sorted)):
    jumlah += data_konsol_sorted['Pertambahan'].iloc[j]
    input_data["Jumlah"][j] = jumlah
JumlahTiapTahun = pd.DataFrame(data=input_data)

title1 = "Produksi Game Platform " + keyword
title2 = "Jumlah Game Platform "+ keyword
data_konsol.sort_values('Tahun').plot(kind="line",x="Tahun",y="Pertambahan",title=title1, ylabel="Pertambahan")
JumlahTiapTahun.plot(kind="line",x="Tahun",y="Jumlah", title=title2, ylabel="Jumlah")
# Out:
# <AxesSubplot: title={'center': 'Jumlah Game Platform X360'}, xlabel='Tahun', ylabel='Jumlah'>

# %% [markdown]
# #### Menampilkan Peningkatan Jumlah Game di Semua Platform

# %%
# Menunjukkan semua perkembangan game untuk semua konsol

for i in range(len(list_console)):
    keyword = list_console['Jenis Konsol'].iloc[i]

    #memuat data konsol
    hasil_search = data.loc[data['Platform'] == keyword]
    publish_konsol = hasil_search.value_counts('Year')

    input_data_konsol = {}
    input_data_konsol["Tahun"] = [0 for i in range(len(publish_konsol))]
    input_data_konsol["Pertambahan"] = [0 for i in range(len(publish_konsol))]

    for i in range(len(publish_konsol)):
        input_data_konsol["Tahun"][i] = publish_konsol.index[i]
    for j in range(len(publish_konsol)):
        input_data_konsol["Pertambahan"][j] = publish_konsol.iloc[j]
    data_konsol = pd.DataFrame(data=input_data_konsol)

    data_konsol_sorted = data_konsol.sort_values('Tahun',ascending=True)

    input_data = {}
    input_data["Tahun"] = [0 for i in range(len(data_konsol_sorted))]
    input_data["Jumlah"] = [0 for i in range(len(data_konsol_sorted))]

    for i in range(len(data_konsol_sorted)):
        input_data["Tahun"][i] = data_konsol_sorted['Tahun'].iloc[i]
    jumlah = 0

    for j in range(len(data_konsol_sorted)):
        jumlah += data_konsol_sorted['Pertambahan'].iloc[j]
        input_data["Jumlah"][j] = jumlah
    JumlahTiapTahun = pd.DataFrame(data=input_data)

    title1 = "Produksi Game Platform " + keyword
    title2 = "Jumlah Game Platform "+ keyword
    data_konsol.sort_values('Tahun').plot(kind="line",x="Tahun",y="Pertambahan",title=title1, ylabel="Pertambahan").locator_params(integer=True)
    JumlahTiapTahun.plot(kind="line",x="Tahun",y="Jumlah", title=title2, ylabel="Jumlah").locator_params(integer=True)

    plt.show()

# %% [markdown]
# #### Analisis Data

# %% [markdown]
# 1. Berdasarkan visualisasi data terdapat beberapa platform yang dapat disarankan untuk dibeli agar dapat memainkan game dengan jumlah pilihan terbanyak.

# %%
data.value_counts("Platform").head(15).plot(kind = "pie",title="Jumlah Game Berdasarkan Platform")
# Out:
# <AxesSubplot: title={'center': 'Jumlah Game Berdasarkan Platform'}>

# %% [markdown]
# 2. Berdasarkan data terdapat pilihan game terbaru yang terlaris, kita ambil 10 teratas.

# %%
SortedPublishYear.loc[SortedPublishYear['Year']>=2013].sort_values('Global_Sales',ascending=False).head(10)
# Out:
#                                            Name Platform  Year         Genre  \
# Rank
# 17                           Grand Theft Auto V      PS3  2013        Action
# 24                           Grand Theft Auto V     X360  2013        Action
# 33                          Pokemon X/Pokemon Y      3DS  2013  Role-Playing
# 34                    Call of Duty: Black Ops 3      PS4  2015       Shooter
# 45                           Grand Theft Auto V      PS4  2014        Action
# 50    Pokemon Omega Ruby/Pokemon Alpha Sapphire      3DS  2014  Role-Playing
# 62                         Call of Duty: Ghosts     X360  2013       Shooter
# 68                         Call of Duty: Ghosts      PS3  2013       Shooter
# 73                                    Minecraft     X360  2013          Misc
# 78                                      FIFA 16      PS4  2015        Sports
#
#                    Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Rank
# ...

# %% [markdown]
# 3. Berdasarkan data pada poin nomor 2 didapat urutan konsol yang direkomendasikan untuk memainkan game terbaru yang terlaris.

# %%
SortedPublishYear.loc[SortedPublishYear['Year']>=2013].sort_values('Global_Sales',ascending=False).value_counts('Platform').plot(kind='bar',title='Jumlah Game Tiap Platform', ylabel="Jumlah")
# Out:
# <AxesSubplot: title={'center': 'Jumlah Game Tiap Platform'}, xlabel='Platform', ylabel='Jumlah'>
